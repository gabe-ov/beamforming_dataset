# %% [markdown]
# Declaração de bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Classe Microfone

# %%
class Microfone:
    def __init__(self, position, ganho=1.0, resposta_em_frequencia=None, directividade=1.0, ruido_externo=0.0, ruido_interno=0.0):
        self.position = np.array(position)  # Posição do microfone (x, y)
        self.ganho = ganho
        self.resposta_em_frequencia = resposta_em_frequencia
        self.directividade = directividade
        self.ruido_externo = ruido_externo
        self.ruido_interno = ruido_interno

    def captar_sinal(self, sinal, delay=0):
        sinal_atrasado = np.roll(sinal, int(delay * len(sinal)))
        sinal_captado = (
            self.ganho
            * self.directividade
            * (sinal_atrasado if self.resposta_em_frequencia is None else np.convolve(sinal_atrasado, self.resposta_em_frequencia, mode='same'))
            + np.random.normal(0, self.ruido_externo + self.ruido_interno, len(sinal))
        )
        return sinal_captado

# %% [markdown]
# Calculo do Delay and Sum (DAS)

# %%
def delay_and_sum(distance, captured_signals, microphones):
    summed_signal = np.zeros_like(captured_signals)
    y_source_DAS = int(distance)

    for mic_idx, microphone in enumerate(microphones):
        for other_mic_idx, other_microphone in enumerate(microphones):
            delay = np.sqrt((other_microphone.position[0] - microphone.position[0])**2 + (other_microphone.position[1] - y_source_DAS)**2) / speed_of_sound
            summed_signal[mic_idx] += np.roll(captured_signals[other_mic_idx], int(delay * len(captured_signals[other_mic_idx])))
        summed_signal[mic_idx] = summed_signal[mic_idx] / captured_signals.shape[0]


    return summed_signal

# %%
def salvar_array_csv(nome_arquivo, diretorio, array):
    if not os.path.exists(diretorio):
        os.makedirs(diretorio)

    caminho_arquivo_csv = os.path.join(diretorio, nome_arquivo)

    cabecalho = ';'.join([f'Microfone_{i+1}' for i in range(array.shape[0])])

    array = array.T

    np.savetxt(caminho_arquivo_csv, array, delimiter=';', header=cabecalho)

# %% [markdown]
# Função para gerar um case especifico de microfones, posição da fonte e diferentes freqeucnias de sinal aplicados

# %%
def gerar_dataset():
    num_microphones_list = [64]#[16, 32, 64, 128]
    num_signals_list = [1, 2, 3, 4]
    sample_rate = 10000  # Hz

    num_microphones = np.random.choice(num_microphones_list)
    num_signals = np.random.choice(num_signals_list)
    y_position = np.random.uniform(0, 10)

    source_positions = [(np.random.uniform(0, 6), y_position) for _ in range(num_signals)]
    signals = []

    for _ in range(num_signals):
        frequency = np.random.uniform(200, 15000)
        t = np.arange(0, 1, 1/sample_rate)
        signal = np.sin(2 * np.pi * frequency * t)
        signals.append(signal)

    return np.array(source_positions), np.array(signals), num_microphones, y_position

# %% [markdown]
# Apena um teste para validar a função anterior

# %%
posicoes, sinais, num_microfones, y_position = gerar_dataset()
print("Posições:")
print(posicoes)
print("\nSinais:")
print(sinais)
print("\nNúmero de microfones:")
print(num_microfones)
print("\nY position:")
print(y_position)
# Out:
# Posições:
# [[5.12356922 5.77303535]
#  [4.09164738 5.77303535]]
#
# Sinais:
# [[ 0.          0.13433255 -0.26623001 ...  0.68067636 -0.576097
#    0.46107452]
#  [ 0.          0.82406311  0.93366021 ...  0.16880146  0.90786356
#    0.85980432]]
#
# Número de microfones:
# 64
#
# Y position:
# 5.77303535191866

# %%
len(posicoes)
# Out:
# 2

# %%
sinais.shape
# Out:
# (2, 10000)

# %%
def create_ideal_microphones(num_microphones, x_size, y_size, microphone_line_length):
    # Inicialização dos microfones com espaçamento ao longo da linha
    start_position_mic = (x_size - microphone_line_length) / 2
    microphones = [
        Microfone(
            position=[start_position_mic + (microphone_line_length / (num_microphones - 1) * i), y_size],
            ganho=1.2,
            resposta_em_frequencia= np.ones(100),   #np.random.normal(1, 0.1, 100),  # Exemplo de resposta em frequência aleatória
            directividade= 1.0,     #np.random.uniform(0.5, 1.0),  # Exemplo de directividade aleatória
            ruido_externo= 0.0,     #np.random.uniform(0.005, 0.02),  # Exemplo de ruído externo aleatório
            ruido_interno= 0.0      #np.random.uniform(0.001, 0.01)  # Exemplo de ruído interno aleatório
        )
        for i in range(num_microphones)
    ]
    return microphones

# %%
def create_real_microphones(num_microphones, x_size, y_size, microphone_line_length):
    # Inicialização dos microfones com espaçamento ao longo da linha
    start_position_mic = (x_size - microphone_line_length) / 2
    microphones = [
        Microfone(
            position=[start_position_mic + (microphone_line_length / (num_microphones - 1) * i), y_size],
            ganho=1.2,
            resposta_em_frequencia= np.random.normal(1, 0.1, 100),  # Exemplo de resposta em frequência aleatória
            directividade= np.random.uniform(0.5, 1.0),  # Exemplo de directividade aleatória
            ruido_externo= np.random.uniform(0.005, 0.02),  # Exemplo de ruído externo aleatório
            ruido_interno= np.random.uniform(0.001, 0.01)  # Exemplo de ruído interno aleatório
        )
        for i in range(num_microphones)
    ]
    return microphones

# %%
num_datasets = 100

# %%
x_size = 6  # metros
y_size = 10  # metros
microphone_line_length = 2  # metros
speed_of_sound = 343  # metros por segundo (velocidade do som)

sample_rate = 10000  # Hz
t = np.arange(0, 1, 1/sample_rate)

# %% [markdown]
# Função completa para a criação do dataset

# %%
def datasets(num_datasets):
    for i in range(num_datasets):
        source_positions, signal, num_microphones, y_position = gerar_dataset()
        print("Posições:")
        print(source_positions)
        print("\nSinais:")
        print(signal)
        print("\nNúmero de microfones:")
        print(num_microphones)
        print("\nY position:")
        print(y_position)

        ideal_microphones = create_ideal_microphones(num_microphones, x_size, y_size, microphone_line_length)
        real_microphones = create_real_microphones(num_microphones, x_size, y_size, microphone_line_length)

        delays = np.zeros((num_microphones, len(source_positions)))

        for mic_idx, microphone in enumerate(real_microphones):
            for src_idx, src_coord in enumerate(source_positions):
                distance = np.sqrt((src_coord[0] - microphone.position[0])**2 + (src_coord[1] - microphone.position[1])**2)
                delays[mic_idx, src_idx] = distance / speed_of_sound
        
        captured_signals_ideal = np.zeros((num_microphones, len(t)))
        for mic_idx, (microphone, delay_values) in enumerate(zip(ideal_microphones, delays)):
            for src_idx, delay in enumerate(delay_values):
                captured_signals_ideal[mic_idx, :] += microphone.captar_sinal(signal[src_idx], delay)

        captured_signals_real = np.zeros((num_microphones, len(t)))
        for mic_idx, (microphone, delay_values) in enumerate(zip(real_microphones, delays)):
            for src_idx, delay in enumerate(delay_values):
                captured_signals_real[mic_idx, :] += microphone.captar_sinal(signal[src_idx], delay)

        salvar_array_csv(f'cru_nm{num_microphones}_nss{len(source_positions)}_ypos{(1000*y_position):.0f}_ideal.csv', './64mics/cru', captured_signals_ideal)
        salvar_array_csv(f'cru_nm{num_microphones}_nss{len(source_positions)}_ypos{(1000*y_position):.0f}_real.csv', './64mics/cru', captured_signals_real)

        for i in range (0, 11):
            print(f'i: {i}')
            summed_signal = delay_and_sum(i, captured_signals_real, real_microphones)
            if i < y_position:
                print(f'antes_nm{num_microphones}_nss{len(source_positions)}_ypos{(1000*y_position):.0f}_posDAS{i}_real.csv')
                salvar_array_csv(f'antes_nm{num_microphones}_nss{len(source_positions)}_ypos{(1000*y_position):.0f}_posDAS{i}_real.csv', './64mics/antes', summed_signal)
            else:
                print(f'depois_nm{num_microphones}_nss{len(source_positions)}_ypos{(1000*y_position):.0f}_posDAS{i}_real.csv')
                salvar_array_csv(f'depois_nm{num_microphones}_nss{len(source_positions)}_ypos{(1000*y_position):.0f}_posDAS{i}_real.csv', './64mics/depois', summed_signal)

# %%
datasets(num_datasets)
# Out:
# Posições:
# [[3.80485355 8.82876648]
#  [0.40305734 8.82876648]
#  [4.43824451 8.82876648]]
#
# Sinais:
# [[ 0.          0.96302445 -0.51890453 ...  0.99232376 -0.3864404
#   -0.78409885]
#  [ 0.          0.95845914  0.54676237 ...  0.23880793  0.99884302
#    0.33099182]
#  [ 0.          0.9999908   0.00857841 ...  0.45127863 -0.89043925
#   -0.45891726]]
#
# Número de microfones:
# 64
#
# Y position:
# 8.828766478451044
# i: 0
# antes_nm64_nss3_ypos8829_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos8829_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos8829_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos8829_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos8829_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos8829_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos8829_posDAS6_real.csv
# i: 7
# antes_nm64_nss3_ypos8829_posDAS7_real.csv
# i: 8
# antes_nm64_nss3_ypos8829_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos8829_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos8829_posDAS10_real.csv
# Posições:
# [[5.23049116 3.57990359]
#  [2.53635374 3.57990359]
#  [4.20761885 3.57990359]
#  [5.33733687 3.57990359]]
#
# Sinais:
# [[ 0.         -0.0632976   0.12634135 ...  0.98410375 -0.97088902
#    0.95378043]
#  [ 0.         -0.93030914  0.6824308  ...  0.99636601 -0.4446825
#   -0.67016796]
#  [ 0.          0.76892325 -0.98320847 ... -0.6714917   0.99909365
#   -0.60603157]
#  [ 0.          0.44516141 -0.79723988 ...  0.29843952 -0.69211253
#    0.94106529]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.5799035864281903
# i: 0
# antes_nm64_nss4_ypos3580_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos3580_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos3580_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos3580_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos3580_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos3580_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos3580_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos3580_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos3580_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos3580_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos3580_posDAS10_real.csv
# Posições:
# [[2.69228051 4.11004849]
#  [4.99033434 4.11004849]]
#
# Sinais:
# [[ 0.          0.913559   -0.74310026 ... -0.85652034 -0.12314777
#    0.95669027]
#  [ 0.          0.42529917  0.76983643 ... -0.33373222  0.09887059
#    0.51269844]]
#
# Número de microfones:
# 64
#
# Y position:
# 4.110048492010349
# i: 0
# antes_nm64_nss2_ypos4110_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos4110_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos4110_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos4110_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos4110_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos4110_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos4110_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos4110_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos4110_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos4110_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos4110_posDAS10_real.csv
# Posições:
# [[4.0401015  8.4676511 ]
#  [2.89432999 8.4676511 ]]
#
# Sinais:
# [[ 0.          0.91142838  0.75003038 ... -0.30636241 -0.9936578
#   -0.51133601]
#  [ 0.          0.47536278  0.83643872 ...  0.90318606  0.99866308
#    0.85404128]]
#
# Número de microfones:
# 64
#
# Y position:
# 8.467651095894603
# i: 0
# antes_nm64_nss2_ypos8468_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos8468_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos8468_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos8468_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos8468_posDAS4_real.csv
# i: 5
# antes_nm64_nss2_ypos8468_posDAS5_real.csv
# i: 6
# antes_nm64_nss2_ypos8468_posDAS6_real.csv
# i: 7
# antes_nm64_nss2_ypos8468_posDAS7_real.csv
# i: 8
# antes_nm64_nss2_ypos8468_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos8468_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos8468_posDAS10_real.csv
# Posições:
# [[5.19477408 2.20503106]
#  [0.03755387 2.20503106]]
#
# Sinais:
# [[ 0.         -0.77953484  0.97653712 ... -0.95930337  0.38074507
#    0.48233726]
#  [ 0.         -0.92499909 -0.70294256 ... -0.63159807 -0.95713598
#   -0.09576655]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.20503105710651
# i: 0
# antes_nm64_nss2_ypos2205_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos2205_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos2205_posDAS2_real.csv
# i: 3
# depois_nm64_nss2_ypos2205_posDAS3_real.csv
# i: 4
# depois_nm64_nss2_ypos2205_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos2205_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos2205_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos2205_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos2205_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos2205_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos2205_posDAS10_real.csv
# Posições:
# [[3.66245149 5.54458141]]
#
# Sinais:
# [[ 0.         -0.97922524 -0.39712587 ... -0.74345935  0.50413198
#    0.94791063]]
#
# Número de microfones:
# 64
#
# Y position:
# 5.5445814112734695
# i: 0
# antes_nm64_nss1_ypos5545_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos5545_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos5545_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos5545_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos5545_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos5545_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos5545_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos5545_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos5545_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos5545_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos5545_posDAS10_real.csv
# Posições:
# [[2.67175531 2.79016204]]
#
# Sinais:
# [[ 0.          0.70350847  0.99994847 ... -0.30209985 -0.88533634
#   -0.95629398]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.790162040746057
# i: 0
# antes_nm64_nss1_ypos2790_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos2790_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos2790_posDAS2_real.csv
# i: 3
# depois_nm64_nss1_ypos2790_posDAS3_real.csv
# i: 4
# depois_nm64_nss1_ypos2790_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos2790_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos2790_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos2790_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos2790_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos2790_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos2790_posDAS10_real.csv
# Posições:
# [[3.13079641 1.41200819]
#  [5.50455977 1.41200819]
#  [3.87329769 1.41200819]]
#
# Sinais:
# [[ 0.          0.99999645 -0.0053326  ...  0.04838042 -0.99895443
#   -0.04305337]
#  [ 0.          0.50876056  0.87599214 ...  0.98855705  0.92780197
#    0.60894734]
#  [ 0.          0.37508201  0.69539577 ... -0.99921556 -0.9411182
#   -0.74560183]]
#
# Número de microfones:
# 64
#
# Y position:
# 1.4120081909513005
# i: 0
# antes_nm64_nss3_ypos1412_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos1412_posDAS1_real.csv
# i: 2
# depois_nm64_nss3_ypos1412_posDAS2_real.csv
# i: 3
# depois_nm64_nss3_ypos1412_posDAS3_real.csv
# i: 4
# depois_nm64_nss3_ypos1412_posDAS4_real.csv
# i: 5
# depois_nm64_nss3_ypos1412_posDAS5_real.csv
# i: 6
# depois_nm64_nss3_ypos1412_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos1412_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos1412_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos1412_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos1412_posDAS10_real.csv
# Posições:
# [[0.66970241 1.51327331]
#  [5.18422194 1.51327331]
#  [2.23274486 1.51327331]]
#
# Sinais:
# [[ 0.          0.60035496  0.96024814 ... -0.38359902 -0.86120471
#   -0.99386975]
#  [ 0.          0.34221404 -0.6431037  ... -0.97885159  0.98975781
#   -0.88114489]
#  [ 0.         -0.96735128  0.49032978 ...  0.38667372 -0.99010573
#    0.1151898 ]]
#
# Número de microfones:
# 64
#
# Y position:
# 1.513273313789647
# i: 0
# antes_nm64_nss3_ypos1513_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos1513_posDAS1_real.csv
# i: 2
# depois_nm64_nss3_ypos1513_posDAS2_real.csv
# i: 3
# depois_nm64_nss3_ypos1513_posDAS3_real.csv
# i: 4
# depois_nm64_nss3_ypos1513_posDAS4_real.csv
# i: 5
# depois_nm64_nss3_ypos1513_posDAS5_real.csv
# i: 6
# depois_nm64_nss3_ypos1513_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos1513_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos1513_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos1513_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos1513_posDAS10_real.csv
# Posições:
# [[2.83649014 4.63411701]
#  [4.91976637 4.63411701]
#  [4.02346722 4.63411701]]
#
# Sinais:
# [[ 0.         -0.93727892 -0.65343393 ...  0.997754    0.41058072
#   -0.7115133 ]
#  [ 0.         -0.79145711 -0.96751628 ...  0.31017345 -0.56283675
#   -0.99821291]
#  [ 0.          0.77474332  0.97970303 ...  0.90867904  0.8979876
#    0.22687276]]
#
# Número de microfones:
# 64
#
# Y position:
# 4.634117011495315
# i: 0
# antes_nm64_nss3_ypos4634_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos4634_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos4634_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos4634_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos4634_posDAS4_real.csv
# i: 5
# depois_nm64_nss3_ypos4634_posDAS5_real.csv
# i: 6
# depois_nm64_nss3_ypos4634_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos4634_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos4634_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos4634_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos4634_posDAS10_real.csv
# Posições:
# [[3.48680576 3.60734265]]
#
# Sinais:
# [[ 0.         -0.68609988  0.99828542 ... -0.20300741  0.81950274
#   -0.98938114]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.607342652101803
# i: 0
# antes_nm64_nss1_ypos3607_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos3607_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos3607_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos3607_posDAS3_real.csv
# i: 4
# depois_nm64_nss1_ypos3607_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos3607_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos3607_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos3607_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos3607_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos3607_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos3607_posDAS10_real.csv
# Posições:
# [[4.03355101 4.61494704]
#  [2.07434952 4.61494704]]
#
# Sinais:
# [[ 0.          0.37912057  0.70163638 ... -0.90892041 -0.9991488
#   -0.94019885]
#  [ 0.         -0.23592362  0.45852775 ...  0.34535879 -0.11420245
#   -0.1234014 ]]
#
# Número de microfones:
# 64
#
# Y position:
# 4.614947044737856
# i: 0
# antes_nm64_nss2_ypos4615_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos4615_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos4615_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos4615_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos4615_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos4615_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos4615_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos4615_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos4615_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos4615_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos4615_posDAS10_real.csv
# Posições:
# [[1.46283865 8.85369083]]
#
# Sinais:
# [[ 0.         -0.23058148  0.44873601 ... -0.95675564  0.99804847
#   -0.98555251]]
#
# Número de microfones:
# 64
#
# Y position:
# 8.853690831353912
# i: 0
# antes_nm64_nss1_ypos8854_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos8854_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos8854_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos8854_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos8854_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos8854_posDAS5_real.csv
# i: 6
# antes_nm64_nss1_ypos8854_posDAS6_real.csv
# i: 7
# antes_nm64_nss1_ypos8854_posDAS7_real.csv
# i: 8
# antes_nm64_nss1_ypos8854_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos8854_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos8854_posDAS10_real.csv
# Posições:
# [[0.42365553 3.82407079]
#  [4.19744599 3.82407079]
#  [2.75452061 3.82407079]
#  [3.64516751 3.82407079]]
#
# Sinais:
# [[ 0.          0.98250636 -0.36594243 ...  0.96237648 -0.44618862
#   -0.79618993]
#  [ 0.          0.7228437  -0.99898671 ...  0.3621305   0.42354606
#   -0.94748095]
#  [ 0.          0.64800072 -0.98708618 ... -0.75657941  0.99996979
#   -0.76665402]
#  [ 0.         -0.20463223 -0.40060399 ...  0.58370397  0.40519764
#    0.20954248]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.8240707854022316
# i: 0
# antes_nm64_nss4_ypos3824_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos3824_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos3824_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos3824_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos3824_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos3824_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos3824_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos3824_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos3824_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos3824_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos3824_posDAS10_real.csv
# Posições:
# [[1.19786597 5.32587856]
#  [5.79142463 5.32587856]]
#
# Sinais:
# [[ 0.          0.49478285 -0.85994907 ... -0.09338545  0.57377418
#   -0.90385317]
#  [ 0.          0.72097686  0.99921501 ...  0.80387647  0.9858879
#    0.5624836 ]]
#
# Número de microfones:
# 64
#
# Y position:
# 5.325878559439177
# i: 0
# antes_nm64_nss2_ypos5326_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos5326_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos5326_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos5326_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos5326_posDAS4_real.csv
# i: 5
# antes_nm64_nss2_ypos5326_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos5326_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos5326_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos5326_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos5326_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos5326_posDAS10_real.csv
# Posições:
# [[3.50317096 2.16892799]
#  [5.45008601 2.16892799]
#  [0.73013336 2.16892799]
#  [0.89198008 2.16892799]]
#
# Sinais:
# [[ 0.         -0.95619594 -0.5598095  ...  0.4685882   0.98188808
#    0.10626289]
#  [ 0.          0.8789956  -0.83826274 ...  0.50255668  0.52029656
#   -0.99874257]
#  [ 0.         -0.16602415  0.32744003 ... -0.66030164  0.52645355
#   -0.37799288]
#  [ 0.          0.1379838  -0.27332783 ...  0.99947737 -0.99437735
#    0.97025388]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.1689279934921535
# i: 0
# antes_nm64_nss4_ypos2169_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos2169_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos2169_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos2169_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos2169_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos2169_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos2169_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos2169_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos2169_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos2169_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos2169_posDAS10_real.csv
# Posições:
# [[3.43942334 3.29302096]]
#
# Sinais:
# [[ 0.          0.52581577 -0.89451619 ... -0.39723472 -0.14466284
#    0.64333471]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.2930209570275224
# i: 0
# antes_nm64_nss1_ypos3293_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos3293_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos3293_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos3293_posDAS3_real.csv
# i: 4
# depois_nm64_nss1_ypos3293_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos3293_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos3293_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos3293_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos3293_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos3293_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos3293_posDAS10_real.csv
# Posições:
# [[1.79743288 1.77239466]
#  [4.18564656 1.77239466]]
#
# Sinais:
# [[ 0.          0.88424821  0.82591832 ...  0.70705806  0.95550929
#    0.18542057]
#  [ 0.         -0.97493165  0.43385346 ... -0.99840883  0.27712667
#    0.87508494]]
#
# Número de microfones:
# 64
#
# Y position:
# 1.7723946615521768
# i: 0
# antes_nm64_nss2_ypos1772_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos1772_posDAS1_real.csv
# i: 2
# depois_nm64_nss2_ypos1772_posDAS2_real.csv
# i: 3
# depois_nm64_nss2_ypos1772_posDAS3_real.csv
# i: 4
# depois_nm64_nss2_ypos1772_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos1772_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos1772_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos1772_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos1772_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos1772_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos1772_posDAS10_real.csv
# Posições:
# [[4.46499724 8.12536863]]
#
# Sinais:
# [[ 0.          0.00725588 -0.01451137 ... -0.27730538  0.28426939
#   -0.29121843]]
#
# Número de microfones:
# 64
#
# Y position:
# 8.125368634559461
# i: 0
# antes_nm64_nss1_ypos8125_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos8125_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos8125_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos8125_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos8125_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos8125_posDAS5_real.csv
# i: 6
# antes_nm64_nss1_ypos8125_posDAS6_real.csv
# i: 7
# antes_nm64_nss1_ypos8125_posDAS7_real.csv
# i: 8
# antes_nm64_nss1_ypos8125_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos8125_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos8125_posDAS10_real.csv
# Posições:
# [[5.15428126 7.66217546]]
#
# Sinais:
# [[ 0.          0.71369731 -0.99982462 ... -0.15283152  0.81236446
#   -0.98521676]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.662175457191852
# i: 0
# antes_nm64_nss1_ypos7662_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos7662_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos7662_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos7662_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos7662_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos7662_posDAS5_real.csv
# i: 6
# antes_nm64_nss1_ypos7662_posDAS6_real.csv
# i: 7
# antes_nm64_nss1_ypos7662_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos7662_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos7662_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos7662_posDAS10_real.csv
# Posições:
# [[5.32934782 5.28773139]
#  [4.33797056 5.28773139]
#  [1.66529329 5.28773139]]
#
# Sinais:
# [[ 0.          0.81040229 -0.94958696 ...  0.9388175  -0.27091388
#   -0.62137481]
#  [ 0.         -0.22903777 -0.44589877 ...  0.90302658  0.97741303
#    0.99983538]
#  [ 0.          0.99742515  0.14306116 ...  0.29621016  0.97390627
#   -0.15652233]]
#
# Número de microfones:
# 64
#
# Y position:
# 5.287731385647419
# i: 0
# antes_nm64_nss3_ypos5288_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos5288_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos5288_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos5288_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos5288_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos5288_posDAS5_real.csv
# i: 6
# depois_nm64_nss3_ypos5288_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos5288_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos5288_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos5288_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos5288_posDAS10_real.csv
# Posições:
# [[1.46434784 9.00450276]
#  [1.43263125 9.00450276]]
#
# Sinais:
# [[ 0.          0.84135543  0.90947531 ... -0.99343142 -0.63320753
#    0.3089566 ]
#  [ 0.          0.11091967 -0.22047046 ... -0.8267919   0.75929689
#   -0.68243119]]
#
# Número de microfones:
# 64
#
# Y position:
# 9.004502758083392
# i: 0
# antes_nm64_nss2_ypos9005_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos9005_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos9005_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos9005_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos9005_posDAS4_real.csv
# i: 5
# antes_nm64_nss2_ypos9005_posDAS5_real.csv
# i: 6
# antes_nm64_nss2_ypos9005_posDAS6_real.csv
# i: 7
# antes_nm64_nss2_ypos9005_posDAS7_real.csv
# i: 8
# antes_nm64_nss2_ypos9005_posDAS8_real.csv
# i: 9
# antes_nm64_nss2_ypos9005_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos9005_posDAS10_real.csv
# Posições:
# [[4.22562561 8.89338359]
#  [4.37351262 8.89338359]
#  [4.99677529 8.89338359]]
#
# Sinais:
# [[ 0.          0.30563141  0.58201383 ...  0.92823476  0.99751197
#    0.97132711]
#  [ 0.          0.72190496  0.99910523 ...  0.98100409  0.538807
#   -0.23530359]
#  [ 0.         -0.76112442  0.98733958 ... -0.81350641  0.08500863
#    0.70323222]]
#
# Número de microfones:
# 64
#
# Y position:
# 8.893383591620061
# i: 0
# antes_nm64_nss3_ypos8893_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos8893_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos8893_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos8893_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos8893_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos8893_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos8893_posDAS6_real.csv
# i: 7
# antes_nm64_nss3_ypos8893_posDAS7_real.csv
# i: 8
# antes_nm64_nss3_ypos8893_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos8893_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos8893_posDAS10_real.csv
# Posições:
# [[3.3665847  3.13876627]
#  [2.82687669 3.13876627]
#  [5.71528275 3.13876627]]
#
# Sinais:
# [[ 0.          0.24993275 -0.48400137 ... -0.47091527  0.23548464
#    0.01489304]
#  [ 0.          0.9797139  -0.39267182 ...  0.98608113 -0.36050392
#   -0.84159024]
#  [ 0.          0.56169983  0.92943471 ... -0.14227436  0.43827638
#    0.86748249]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.1387662725351273
# i: 0
# antes_nm64_nss3_ypos3139_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos3139_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos3139_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos3139_posDAS3_real.csv
# i: 4
# depois_nm64_nss3_ypos3139_posDAS4_real.csv
# i: 5
# depois_nm64_nss3_ypos3139_posDAS5_real.csv
# i: 6
# depois_nm64_nss3_ypos3139_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos3139_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos3139_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos3139_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos3139_posDAS10_real.csv
# Posições:
# [[4.69501406 3.49072561]
#  [2.89560004 3.49072561]]
#
# Sinais:
# [[ 0.          0.75972893 -0.98801216 ... -0.42659411 -0.40974313
#    0.95945679]
#  [ 0.          0.87675365  0.84333134 ... -0.20307514  0.76081797
#    0.93489033]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.490725610511969
# i: 0
# antes_nm64_nss2_ypos3491_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos3491_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos3491_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos3491_posDAS3_real.csv
# i: 4
# depois_nm64_nss2_ypos3491_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos3491_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos3491_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos3491_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos3491_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos3491_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos3491_posDAS10_real.csv
# Posições:
# [[4.91368449 0.5875691 ]
#  [4.99769128 0.5875691 ]
#  [1.55373816 0.5875691 ]
#  [4.44657561 0.5875691 ]]
#
# Sinais:
# [[ 0.          0.9197705   0.72194012 ... -0.42031168 -0.99953528
#   -0.36423689]
#  [ 0.          0.91964031 -0.72239885 ...  0.25758628 -0.98977733
#    0.51990683]
#  [ 0.          0.98620017  0.32654525 ... -0.67545645 -0.83905063
#    0.39763456]
#  [ 0.          0.15240253 -0.30124449 ...  0.41425659 -0.27070675
#    0.12083238]]
#
# Número de microfones:
# 64
#
# Y position:
# 0.587569102282004
# i: 0
# antes_nm64_nss4_ypos588_posDAS0_real.csv
# i: 1
# depois_nm64_nss4_ypos588_posDAS1_real.csv
# i: 2
# depois_nm64_nss4_ypos588_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos588_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos588_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos588_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos588_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos588_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos588_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos588_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos588_posDAS10_real.csv
# Posições:
# [[0.86900539 2.15817103]]
#
# Sinais:
# [[ 0.         -0.97625074  0.42299718 ...  0.95238828  0.09131801
#   -0.99195522]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.158171026048504
# i: 0
# antes_nm64_nss1_ypos2158_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos2158_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos2158_posDAS2_real.csv
# i: 3
# depois_nm64_nss1_ypos2158_posDAS3_real.csv
# i: 4
# depois_nm64_nss1_ypos2158_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos2158_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos2158_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos2158_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos2158_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos2158_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos2158_posDAS10_real.csv
# Posições:
# [[1.72092372 6.58462031]]
#
# Sinais:
# [[ 0.         -0.26055579 -0.50311175 ... -0.57181285 -0.33830592
#   -0.081428  ]]
#
# Número de microfones:
# 64
#
# Y position:
# 6.584620311819206
# i: 0
# antes_nm64_nss1_ypos6585_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos6585_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos6585_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos6585_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos6585_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos6585_posDAS5_real.csv
# i: 6
# antes_nm64_nss1_ypos6585_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos6585_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos6585_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos6585_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos6585_posDAS10_real.csv
# Posições:
# [[2.76231579 7.2677979 ]
#  [3.85593034 7.2677979 ]]
#
# Sinais:
# [[ 0.          0.29505086  0.5638313  ... -0.24848726 -0.52322163
#   -0.75136996]
#  [ 0.         -0.65382884 -0.98942936 ...  0.80312569  0.21812149
#   -0.47304572]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.2677978977221365
# i: 0
# antes_nm64_nss2_ypos7268_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos7268_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos7268_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos7268_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos7268_posDAS4_real.csv
# i: 5
# antes_nm64_nss2_ypos7268_posDAS5_real.csv
# i: 6
# antes_nm64_nss2_ypos7268_posDAS6_real.csv
# i: 7
# antes_nm64_nss2_ypos7268_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos7268_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos7268_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos7268_posDAS10_real.csv
# Posições:
# [[5.70720345 7.20409079]
#  [4.46183851 7.20409079]
#  [0.63508794 7.20409079]
#  [0.41265633 7.20409079]]
#
# Sinais:
# [[ 0.          0.30401679 -0.57925333 ...  0.05031085  0.25570231
#   -0.537509  ]
#  [ 0.          0.02697341 -0.05392719 ... -0.47156602  0.44760846
#   -0.42332518]
#  [ 0.         -0.97227546 -0.45471078 ...  0.98140627  0.41611103
#   -0.78680075]
#  [ 0.          0.89912326 -0.78708445 ...  0.36676171  0.67593782
#   -0.95847163]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.204090790933458
# i: 0
# antes_nm64_nss4_ypos7204_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos7204_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos7204_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos7204_posDAS3_real.csv
# i: 4
# antes_nm64_nss4_ypos7204_posDAS4_real.csv
# i: 5
# antes_nm64_nss4_ypos7204_posDAS5_real.csv
# i: 6
# antes_nm64_nss4_ypos7204_posDAS6_real.csv
# i: 7
# antes_nm64_nss4_ypos7204_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos7204_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos7204_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos7204_posDAS10_real.csv
# Posições:
# [[5.78663866 9.86960516]
#  [3.03241371 9.86960516]
#  [5.1392011  9.86960516]]
#
# Sinais:
# [[ 0.          0.88231393 -0.83054218 ... -0.37244364  0.99413052
#   -0.56335404]
#  [ 0.          0.81816324  0.94086484 ... -0.48126305 -0.99390196
#   -0.66169641]
#  [ 0.          0.99688642 -0.15721091 ... -0.8512297   0.59027958
#    0.75814148]]
#
# Número de microfones:
# 64
#
# Y position:
# 9.869605161631013
# i: 0
# antes_nm64_nss3_ypos9870_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos9870_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos9870_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos9870_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos9870_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos9870_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos9870_posDAS6_real.csv
# i: 7
# antes_nm64_nss3_ypos9870_posDAS7_real.csv
# i: 8
# antes_nm64_nss3_ypos9870_posDAS8_real.csv
# i: 9
# antes_nm64_nss3_ypos9870_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos9870_posDAS10_real.csv
# Posições:
# [[4.4142139  4.41962235]]
#
# Sinais:
# [[ 0.          0.62036647 -0.97312183 ... -0.99758925  0.73937091
#   -0.16220583]]
#
# Número de microfones:
# 64
#
# Y position:
# 4.419622347811973
# i: 0
# antes_nm64_nss1_ypos4420_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos4420_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos4420_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos4420_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos4420_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos4420_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos4420_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos4420_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos4420_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos4420_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos4420_posDAS10_real.csv
# Posições:
# [[1.81323504 9.96477206]
#  [2.36392413 9.96477206]]
#
# Sinais:
# [[ 0.          0.54969141  0.918389   ... -0.02774354  0.52630376
#    0.90705796]
#  [ 0.         -0.79662486 -0.96307805 ... -0.14681091  0.69924971
#    0.99216747]]
#
# Número de microfones:
# 64
#
# Y position:
# 9.964772055391935
# i: 0
# antes_nm64_nss2_ypos9965_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos9965_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos9965_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos9965_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos9965_posDAS4_real.csv
# i: 5
# antes_nm64_nss2_ypos9965_posDAS5_real.csv
# i: 6
# antes_nm64_nss2_ypos9965_posDAS6_real.csv
# i: 7
# antes_nm64_nss2_ypos9965_posDAS7_real.csv
# i: 8
# antes_nm64_nss2_ypos9965_posDAS8_real.csv
# i: 9
# antes_nm64_nss2_ypos9965_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos9965_posDAS10_real.csv
# Posições:
# [[1.1540971  1.88938747]]
#
# Sinais:
# [[ 0.          0.98387608 -0.35193544 ...  0.79020138 -0.74429448
#   -0.523965  ]]
#
# Número de microfones:
# 64
#
# Y position:
# 1.889387471387739
# i: 0
# antes_nm64_nss1_ypos1889_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos1889_posDAS1_real.csv
# i: 2
# depois_nm64_nss1_ypos1889_posDAS2_real.csv
# i: 3
# depois_nm64_nss1_ypos1889_posDAS3_real.csv
# i: 4
# depois_nm64_nss1_ypos1889_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos1889_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos1889_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos1889_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos1889_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos1889_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos1889_posDAS10_real.csv
# Posições:
# [[4.7066114  4.47796989]]
#
# Sinais:
# [[ 0.          0.38439624 -0.70972477 ... -0.99647746  0.88768044
#   -0.64247926]]
#
# Número de microfones:
# 64
#
# Y position:
# 4.477969889096326
# i: 0
# antes_nm64_nss1_ypos4478_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos4478_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos4478_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos4478_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos4478_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos4478_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos4478_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos4478_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos4478_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos4478_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos4478_posDAS10_real.csv
# Posições:
# [[3.09416868 7.56877131]
#  [3.77609284 7.56877131]
#  [1.7360868  7.56877131]
#  [4.04138009 7.56877131]]
#
# Sinais:
# [[ 0.          0.29190305  0.55838012 ...  0.94934207  0.8162673
#    0.61209225]
#  [ 0.          0.50343615 -0.86997032 ...  0.56971528 -0.07850744
#   -0.43404933]
#  [ 0.          0.62911734 -0.97803883 ... -0.54990408  0.95290243
#   -0.93149776]
#  [ 0.          0.7318348  -0.9974646  ...  0.97355421 -0.49626761
#   -0.29715923]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.568771313555393
# i: 0
# antes_nm64_nss4_ypos7569_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos7569_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos7569_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos7569_posDAS3_real.csv
# i: 4
# antes_nm64_nss4_ypos7569_posDAS4_real.csv
# i: 5
# antes_nm64_nss4_ypos7569_posDAS5_real.csv
# i: 6
# antes_nm64_nss4_ypos7569_posDAS6_real.csv
# i: 7
# antes_nm64_nss4_ypos7569_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos7569_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos7569_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos7569_posDAS10_real.csv
# Posições:
# [[2.5580927  9.07258476]
#  [5.86317289 9.07258476]
#  [4.82642406 9.07258476]]
#
# Sinais:
# [[ 0.         -0.91017104 -0.75404509 ...  0.95835358  0.65691192
#   -0.41412488]
#  [ 0.          0.07721164 -0.15396229 ... -0.17706236  0.10054211
#   -0.02342157]
#  [ 0.         -0.264036    0.50933222 ... -0.7756974   0.91480454
#   -0.98898402]]
#
# Número de microfones:
# 64
#
# Y position:
# 9.072584764855439
# i: 0
# antes_nm64_nss3_ypos9073_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos9073_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos9073_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos9073_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos9073_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos9073_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos9073_posDAS6_real.csv
# i: 7
# antes_nm64_nss3_ypos9073_posDAS7_real.csv
# i: 8
# antes_nm64_nss3_ypos9073_posDAS8_real.csv
# i: 9
# antes_nm64_nss3_ypos9073_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos9073_posDAS10_real.csv
# Posições:
# [[3.76937236 7.16720716]]
#
# Sinais:
# [[ 0.          0.66850232 -0.9943438  ... -0.17493834 -0.5280902
#    0.96043033]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.167207157996062
# i: 0
# antes_nm64_nss1_ypos7167_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos7167_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos7167_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos7167_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos7167_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos7167_posDAS5_real.csv
# i: 6
# antes_nm64_nss1_ypos7167_posDAS6_real.csv
# i: 7
# antes_nm64_nss1_ypos7167_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos7167_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos7167_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos7167_posDAS10_real.csv
# Posições:
# [[0.10940517 9.35207342]
#  [5.51472941 9.35207342]
#  [3.51860821 9.35207342]
#  [1.67464556 9.35207342]]
#
# Sinais:
# [[ 0.         -0.79582541 -0.96378619 ... -0.71115454  0.12887102
#    0.86722408]
#  [ 0.          0.39199064 -0.72123863 ... -0.70760026  0.37398478
#    0.01949129]
#  [ 0.         -0.80328144  0.95686827 ... -0.71637967  0.9871335
#   -0.45949304]
#  [ 0.          0.52657626 -0.89531433 ...  0.77885885 -0.33186141
#   -0.21460956]]
#
# Número de microfones:
# 64
#
# Y position:
# 9.352073419829615
# i: 0
# antes_nm64_nss4_ypos9352_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos9352_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos9352_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos9352_posDAS3_real.csv
# i: 4
# antes_nm64_nss4_ypos9352_posDAS4_real.csv
# i: 5
# antes_nm64_nss4_ypos9352_posDAS5_real.csv
# i: 6
# antes_nm64_nss4_ypos9352_posDAS6_real.csv
# i: 7
# antes_nm64_nss4_ypos9352_posDAS7_real.csv
# i: 8
# antes_nm64_nss4_ypos9352_posDAS8_real.csv
# i: 9
# antes_nm64_nss4_ypos9352_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos9352_posDAS10_real.csv
# Posições:
# [[5.39467443 6.85335498]]
#
# Sinais:
# [[ 0.          0.74411495  0.99421437 ...  0.99873214  0.70466332
#   -0.05722923]]
#
# Número de microfones:
# 64
#
# Y position:
# 6.853354976443131
# i: 0
# antes_nm64_nss1_ypos6853_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos6853_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos6853_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos6853_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos6853_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos6853_posDAS5_real.csv
# i: 6
# antes_nm64_nss1_ypos6853_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos6853_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos6853_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos6853_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos6853_posDAS10_real.csv
# Posições:
# [[2.46521947 5.87214193]
#  [5.48230305 5.87214193]]
#
# Sinais:
# [[ 0.         -0.60348137 -0.96240445 ...  0.965663    0.61321434
#    0.01226313]
#  [ 0.          0.48749869 -0.85129334 ...  0.96845731 -0.96705774
#    0.72026479]]
#
# Número de microfones:
# 64
#
# Y position:
# 5.872141930724657
# i: 0
# antes_nm64_nss2_ypos5872_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos5872_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos5872_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos5872_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos5872_posDAS4_real.csv
# i: 5
# antes_nm64_nss2_ypos5872_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos5872_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos5872_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos5872_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos5872_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos5872_posDAS10_real.csv
# Posições:
# [[3.45214212 3.10916325]
#  [3.8140958  3.10916325]
#  [3.22521036 3.10916325]
#  [1.03733115 3.10916325]]
#
# Sinais:
# [[ 0.         -0.62359095  0.97498546 ... -0.92270173  0.4809194
#    0.17078347]
#  [ 0.         -0.99994525  0.0209263  ...  0.59365906 -0.8108845
#   -0.57668932]
#  [ 0.          0.45324912 -0.80803793 ...  0.30063596  0.16429929
#   -0.59354345]
#  [ 0.          0.4874971   0.85129143 ...  0.9637645   0.97152856
#    0.73276648]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.1091632455494644
# i: 0
# antes_nm64_nss4_ypos3109_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos3109_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos3109_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos3109_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos3109_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos3109_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos3109_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos3109_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos3109_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos3109_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos3109_posDAS10_real.csv
# Posições:
# [[3.13614569 0.5916994 ]
#  [4.76185761 0.5916994 ]
#  [1.89385742 0.5916994 ]]
#
# Sinais:
# [[ 0.         -0.98114881 -0.37922137 ...  0.89784933 -0.25848984
#   -0.99775759]
#  [ 0.          0.46342143  0.82131069 ... -0.85033741 -0.99738621
#   -0.91730626]
#  [ 0.          0.1780262  -0.35036472 ... -0.99176047  0.95311159
#   -0.88401223]]
#
# Número de microfones:
# 64
#
# Y position:
# 0.5916993968788165
# i: 0
# antes_nm64_nss3_ypos592_posDAS0_real.csv
# i: 1
# depois_nm64_nss3_ypos592_posDAS1_real.csv
# i: 2
# depois_nm64_nss3_ypos592_posDAS2_real.csv
# i: 3
# depois_nm64_nss3_ypos592_posDAS3_real.csv
# i: 4
# depois_nm64_nss3_ypos592_posDAS4_real.csv
# i: 5
# depois_nm64_nss3_ypos592_posDAS5_real.csv
# i: 6
# depois_nm64_nss3_ypos592_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos592_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos592_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos592_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos592_posDAS10_real.csv
# Posições:
# [[5.83938578 6.85990212]
#  [3.65077886 6.85990212]
#  [1.63709728 6.85990212]]
#
# Sinais:
# [[ 0.         -0.98061666 -0.38427649 ... -0.17809256  0.93004549
#    0.54255162]
#  [ 0.          0.92722437  0.69450272 ...  0.03553174 -0.91333202
#   -0.71962891]
#  [ 0.         -0.93074739 -0.68067944 ...  0.77213434  0.87379293
#   -0.13310716]]
#
# Número de microfones:
# 64
#
# Y position:
# 6.859902117832704
# i: 0
# antes_nm64_nss3_ypos6860_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos6860_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos6860_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos6860_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos6860_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos6860_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos6860_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos6860_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos6860_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos6860_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos6860_posDAS10_real.csv
# Posições:
# [[3.54353522 8.64502564]
#  [5.36354225 8.64502564]]
#
# Sinais:
# [[ 0.          0.66425076 -0.99306793 ... -0.59009483 -0.0951705
#    0.73237659]
#  [ 0.          0.56758906  0.93460578 ...  0.87465684  0.44498086
#   -0.14194067]]
#
# Número de microfones:
# 64
#
# Y position:
# 8.645025639772188
# i: 0
# antes_nm64_nss2_ypos8645_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos8645_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos8645_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos8645_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos8645_posDAS4_real.csv
# i: 5
# antes_nm64_nss2_ypos8645_posDAS5_real.csv
# i: 6
# antes_nm64_nss2_ypos8645_posDAS6_real.csv
# i: 7
# antes_nm64_nss2_ypos8645_posDAS7_real.csv
# i: 8
# antes_nm64_nss2_ypos8645_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos8645_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos8645_posDAS10_real.csv
# Posições:
# [[1.4118634  3.88971407]
#  [5.64489089 3.88971407]]
#
# Sinais:
# [[ 0.          0.3160854   0.59975987 ... -0.92866087 -0.99829464
#   -0.96556476]
#  [ 0.          0.9999981   0.00390289 ...  0.79055892  0.61392755
#   -0.78816283]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.8897140739875393
# i: 0
# antes_nm64_nss2_ypos3890_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos3890_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos3890_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos3890_posDAS3_real.csv
# i: 4
# depois_nm64_nss2_ypos3890_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos3890_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos3890_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos3890_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos3890_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos3890_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos3890_posDAS10_real.csv
# Posições:
# [[5.12350123 1.4730944 ]
#  [3.10323216 1.4730944 ]]
#
# Sinais:
# [[ 0.          0.16856693  0.33230954 ...  0.0703875  -0.09876857
#   -0.26509792]
#  [ 0.          0.5199868  -0.88831872 ...  0.33656325 -0.7771349
#    0.99105405]]
#
# Número de microfones:
# 64
#
# Y position:
# 1.4730943994514345
# i: 0
# antes_nm64_nss2_ypos1473_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos1473_posDAS1_real.csv
# i: 2
# depois_nm64_nss2_ypos1473_posDAS2_real.csv
# i: 3
# depois_nm64_nss2_ypos1473_posDAS3_real.csv
# i: 4
# depois_nm64_nss2_ypos1473_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos1473_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos1473_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos1473_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos1473_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos1473_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos1473_posDAS10_real.csv
# Posições:
# [[1.41141236 2.51485689]]
#
# Sinais:
# [[ 0.          0.848956   -0.89728459 ...  0.78051677  0.11823731
#   -0.90548499]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.5148568892990077
# i: 0
# antes_nm64_nss1_ypos2515_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos2515_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos2515_posDAS2_real.csv
# i: 3
# depois_nm64_nss1_ypos2515_posDAS3_real.csv
# i: 4
# depois_nm64_nss1_ypos2515_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos2515_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos2515_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos2515_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos2515_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos2515_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos2515_posDAS10_real.csv
# Posições:
# [[1.92953599 7.38384274]
#  [3.72490325 7.38384274]
#  [1.12218155 7.38384274]]
#
# Sinais:
# [[ 0.          0.92814583 -0.69094286 ...  0.47558001  0.63944549
#   -0.95160466]
#  [ 0.          0.84130985  0.90954543 ... -0.57528723 -0.99912397
#   -0.50487205]
#  [ 0.         -0.91548184 -0.73670524 ... -0.592575    0.49900657
#    0.99413485]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.3838427430693265
# i: 0
# antes_nm64_nss3_ypos7384_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos7384_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos7384_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos7384_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos7384_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos7384_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos7384_posDAS6_real.csv
# i: 7
# antes_nm64_nss3_ypos7384_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos7384_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos7384_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos7384_posDAS10_real.csv
# Posições:
# [[2.43270223 7.31933442]
#  [0.91968424 7.31933442]
#  [1.98891211 7.31933442]]
#
# Sinais:
# [[ 0.         -0.60843355  0.9657116  ...  0.94446587 -0.94946973
#    0.56254164]
#  [ 0.          0.23963172  0.46529956 ...  0.11251927  0.34735085
#    0.5619415 ]
#  [ 0.          0.93352284 -0.66936937 ... -0.85742723 -0.17299269
#    0.9814692 ]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.319334417277044
# i: 0
# antes_nm64_nss3_ypos7319_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos7319_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos7319_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos7319_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos7319_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos7319_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos7319_posDAS6_real.csv
# i: 7
# antes_nm64_nss3_ypos7319_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos7319_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos7319_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos7319_posDAS10_real.csv
# Posições:
# [[1.00588797 2.82687299]
#  [3.68943988 2.82687299]
#  [0.0662952  2.82687299]
#  [2.76670171 2.82687299]]
#
# Sinais:
# [[ 0.          0.59236087  0.95449804 ... -0.97903586 -0.9094393
#   -0.48638508]
#  [ 0.          0.38598663  0.71214871 ... -0.03376079 -0.41691107
#   -0.73544378]
#  [ 0.          0.98701908  0.31703655 ... -0.62543948 -0.87059151
#    0.34580017]
#  [ 0.         -0.89541308  0.79734091 ... -0.41786588  0.99953968
#   -0.47219692]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.8268729899481135
# i: 0
# antes_nm64_nss4_ypos2827_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos2827_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos2827_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos2827_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos2827_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos2827_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos2827_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos2827_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos2827_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos2827_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos2827_posDAS10_real.csv
# Posições:
# [[5.85416048 4.29058006]
#  [3.64087523 4.29058006]
#  [3.8029951  4.29058006]
#  [2.61535443 4.29058006]]
#
# Sinais:
# [[ 0.          0.9652061  -0.50478409 ...  0.9374546   0.09086024
#   -0.98497275]
#  [ 0.          0.8329865  -0.92177173 ...  0.66459545  0.2546941
#   -0.94643654]
#  [ 0.          0.61417121 -0.96937444 ...  0.99369098 -0.85307489
#    0.35275604]
#  [ 0.          0.92391801  0.70696456 ... -0.57494206 -0.97591168
#   -0.17180708]]
#
# Número de microfones:
# 64
#
# Y position:
# 4.290580063249717
# i: 0
# antes_nm64_nss4_ypos4291_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos4291_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos4291_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos4291_posDAS3_real.csv
# i: 4
# antes_nm64_nss4_ypos4291_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos4291_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos4291_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos4291_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos4291_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos4291_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos4291_posDAS10_real.csv
# Posições:
# [[3.44977195 5.83703642]
#  [3.58284874 5.83703642]]
#
# Sinais:
# [[ 0.         -0.882563   -0.82995195 ... -0.57170606  0.45529348
#    0.99985873]
#  [ 0.          0.73762772 -0.99610373 ... -0.71136817 -0.03809798
#    0.76281626]]
#
# Número de microfones:
# 64
#
# Y position:
# 5.837036419578987
# i: 0
# antes_nm64_nss2_ypos5837_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos5837_posDAS1_real.csv
# i: 2
# antes_nm64_nss2_ypos5837_posDAS2_real.csv
# i: 3
# antes_nm64_nss2_ypos5837_posDAS3_real.csv
# i: 4
# antes_nm64_nss2_ypos5837_posDAS4_real.csv
# i: 5
# antes_nm64_nss2_ypos5837_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos5837_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos5837_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos5837_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos5837_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos5837_posDAS10_real.csv
# Posições:
# [[2.46450252 9.81504577]
#  [5.52268238 9.81504577]
#  [4.41089623 9.81504577]]
#
# Sinais:
# [[ 0.          0.19398402  0.38059846 ... -0.64589499 -0.78171851
#   -0.88784406]
#  [ 0.         -0.99431026  0.2118335  ... -0.35451522 -0.89196608
#    0.54454474]
#  [ 0.         -0.1019651   0.20286732 ...  0.10200389 -0.20290549
#    0.301692  ]]
#
# Número de microfones:
# 64
#
# Y position:
# 9.815045766805238
# i: 0
# antes_nm64_nss3_ypos9815_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos9815_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos9815_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos9815_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos9815_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos9815_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos9815_posDAS6_real.csv
# i: 7
# antes_nm64_nss3_ypos9815_posDAS7_real.csv
# i: 8
# antes_nm64_nss3_ypos9815_posDAS8_real.csv
# i: 9
# antes_nm64_nss3_ypos9815_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos9815_posDAS10_real.csv
# Posições:
# [[0.47125265 4.28760164]]
#
# Sinais:
# [[ 0.          0.94935172 -0.59660185 ... -0.94204036  0.61451067
#    0.55586293]]
#
# Número de microfones:
# 64
#
# Y position:
# 4.287601637375786
# i: 0
# antes_nm64_nss1_ypos4288_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos4288_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos4288_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos4288_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos4288_posDAS4_real.csv
# i: 5
# depois_nm64_nss1_ypos4288_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos4288_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos4288_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos4288_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos4288_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos4288_posDAS10_real.csv
# Posições:
# [[5.79943914 0.85838094]
#  [1.05094169 0.85838094]
#  [5.29942796 0.85838094]
#  [0.05813525 0.85838094]]
#
# Sinais:
# [[ 0.         -0.82215001 -0.93605215 ...  0.86698372  0.90325593
#    0.16141092]
#  [ 0.         -0.92577518  0.70002393 ... -0.74289153 -0.33885652
#    0.99911753]
#  [ 0.          0.92886279  0.68814607 ...  0.04256285 -0.91225475
#   -0.71840489]
#  [ 0.         -0.78796701 -0.97033009 ...  0.59758973 -0.26384712
#   -0.92250029]]
#
# Número de microfones:
# 64
#
# Y position:
# 0.8583809437592604
# i: 0
# antes_nm64_nss4_ypos858_posDAS0_real.csv
# i: 1
# depois_nm64_nss4_ypos858_posDAS1_real.csv
# i: 2
# depois_nm64_nss4_ypos858_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos858_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos858_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos858_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos858_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos858_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos858_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos858_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos858_posDAS10_real.csv
# Posições:
# [[2.80377904 2.34769243]
#  [1.61333913 2.34769243]]
#
# Sinais:
# [[ 0.         -0.56630486  0.93349224 ...  0.80854394 -0.3331645
#   -0.25935834]
#  [ 0.          0.55899314  0.92700324 ... -0.98481887 -0.71955161
#   -0.20844563]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.347692434258599
# i: 0
# ...
# i: 6
# antes_nm64_nss2_ypos8803_posDAS6_real.csv
# i: 7
# antes_nm64_nss2_ypos8803_posDAS7_real.csv
# i: 8
# antes_nm64_nss2_ypos8803_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos8803_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos8803_posDAS10_real.csv
# Posições:
# [[1.56005359 9.97484886]
#  [1.77713652 9.97484886]
#  [1.08585806 9.97484886]]
#
# Sinais:
# [[ 0.         -0.99996481 -0.01677813 ...  0.57878171 -0.81059821
#   -0.59238252]
#  [ 0.          0.36759154 -0.68371096 ... -0.5464319   0.20031553
#    0.17385008]
#  [ 0.          0.54512426 -0.91401558 ...  0.92419218 -0.56660329
#    0.02583752]]
#
# Número de microfones:
# 64
#
# Y position:
# 9.974848861755204
# i: 0
# antes_nm64_nss3_ypos9975_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos9975_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos9975_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos9975_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos9975_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos9975_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos9975_posDAS6_real.csv
# i: 7
# antes_nm64_nss3_ypos9975_posDAS7_real.csv
# i: 8
# antes_nm64_nss3_ypos9975_posDAS8_real.csv
# i: 9
# antes_nm64_nss3_ypos9975_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos9975_posDAS10_real.csv
# Posições:
# [[0.34738448 5.72394798]]
#
# Sinais:
# [[ 0.          0.73028223  0.99777814 ... -0.86482818 -0.95745483
#   -0.44333388]]
#
# Número de microfones:
# 64
#
# Y position:
# 5.723947984148552
# i: 0
# antes_nm64_nss1_ypos5724_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos5724_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos5724_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos5724_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos5724_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos5724_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos5724_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos5724_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos5724_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos5724_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos5724_posDAS10_real.csv
# Posições:
# [[4.67194178 3.35281027]
#  [0.39453061 3.35281027]
#  [2.87784871 3.35281027]
#  [1.77183835 3.35281027]]
#
# Sinais:
# [[ 0.         -0.92812535  0.6910224  ... -0.86523641 -0.14322905
#    0.97187555]
#  [ 0.         -0.19398281  0.38059619 ...  0.63645459 -0.77398678
#    0.8821151 ]
#  [ 0.          0.98569042 -0.33230719 ... -0.99656346  0.08633889
#    0.96745591]
#  [ 0.         -0.47203931 -0.83227847 ... -0.89134012 -0.99977742
#   -0.87142244]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.352810270599127
# i: 0
# antes_nm64_nss4_ypos3353_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos3353_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos3353_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos3353_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos3353_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos3353_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos3353_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos3353_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos3353_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos3353_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos3353_posDAS10_real.csv
# Posições:
# [[0.57625923 0.62888685]
#  [2.83385015 0.62888685]
#  [0.36753752 0.62888685]
#  [1.50941515 0.62888685]]
#
# Sinais:
# [[ 0.          0.51697427 -0.88506092 ...  0.31388694  0.22215907
#   -0.69422368]
#  [ 0.          0.5827435   0.94714018 ... -0.93697076 -0.55781994
#    0.03033916]
#  [ 0.         -0.30326741  0.57797035 ... -0.99825036  0.9691701
#   -0.84880467]
#  [ 0.          0.32924593 -0.62177713 ... -0.92412607  0.74679987
#   -0.48619682]]
#
# Número de microfones:
# 64
#
# Y position:
# 0.6288868476041487
# i: 0
# antes_nm64_nss4_ypos629_posDAS0_real.csv
# i: 1
# depois_nm64_nss4_ypos629_posDAS1_real.csv
# i: 2
# depois_nm64_nss4_ypos629_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos629_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos629_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos629_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos629_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos629_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos629_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos629_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos629_posDAS10_real.csv
# Posições:
# [[3.70480087 2.11406714]
#  [3.3446879  2.11406714]
#  [3.19419075 2.11406714]
#  [2.83175568 2.11406714]]
#
# Sinais:
# [[ 0.          0.46652019  0.82528405 ...  0.99270922  0.93429326
#    0.66007528]
#  [ 0.          0.73134437 -0.99756596 ...  0.77891734 -0.98987366
#    0.5712869 ]
#  [ 0.         -0.82211137 -0.93609991 ...  0.36206768  0.9724674
#    0.74523564]
#  [ 0.         -0.15074972 -0.29805388 ...  0.99086491  0.95921144
#    0.90563416]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.1140671399659516
# i: 0
# antes_nm64_nss4_ypos2114_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos2114_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos2114_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos2114_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos2114_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos2114_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos2114_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos2114_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos2114_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos2114_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos2114_posDAS10_real.csv
# Posições:
# [[0.36870778 0.34167693]
#  [5.02870786 0.34167693]]
#
# Sinais:
# [[ 0.         -0.52513101  0.89379545 ...  0.8251008  -0.99886987
#    0.87501847]
#  [ 0.          0.8735776   0.85031402 ... -0.14205312 -0.93385379
#   -0.76693192]]
#
# Número de microfones:
# 64
#
# Y position:
# 0.341676927123743
# i: 0
# antes_nm64_nss2_ypos342_posDAS0_real.csv
# i: 1
# depois_nm64_nss2_ypos342_posDAS1_real.csv
# i: 2
# depois_nm64_nss2_ypos342_posDAS2_real.csv
# i: 3
# depois_nm64_nss2_ypos342_posDAS3_real.csv
# i: 4
# depois_nm64_nss2_ypos342_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos342_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos342_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos342_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos342_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos342_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos342_posDAS10_real.csv
# Posições:
# [[5.02296832 0.5198106 ]
#  [0.85064005 0.5198106 ]
#  [5.7937255  0.5198106 ]
#  [3.48800771 0.5198106 ]]
#
# Sinais:
# [[ 0.          0.99694351 -0.15577397 ... -0.90625119 -0.35064592
#    0.96104017]
#  [ 0.          0.26796799  0.51633564 ... -0.73412145 -0.88922816
#   -0.97929285]
#  [ 0.         -0.60502599 -0.96345031 ...  0.70176866  0.12772874
#   -0.49837195]
#  [ 0.          0.49931596 -0.86523464 ... -0.88556867  0.5353379
#   -0.04208622]]
#
# Número de microfones:
# 64
#
# Y position:
# 0.5198106003093739
# i: 0
# antes_nm64_nss4_ypos520_posDAS0_real.csv
# i: 1
# depois_nm64_nss4_ypos520_posDAS1_real.csv
# i: 2
# depois_nm64_nss4_ypos520_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos520_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos520_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos520_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos520_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos520_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos520_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos520_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos520_posDAS10_real.csv
# Posições:
# [[2.52387569 7.0743566 ]
#  [1.88652402 7.0743566 ]
#  [4.6646357  7.0743566 ]
#  [1.78868227 7.0743566 ]]
#
# Sinais:
# [[ 0.         -0.87196    -0.85378335 ... -0.99999991 -0.48920626
#    0.52099152]
#  [ 0.         -0.00707195  0.01414354 ... -0.99991559  0.9997987
#   -0.9996318 ]
#  [ 0.          0.3268417   0.61778251 ... -0.99666829 -0.9152726
#   -0.73334172]
#  [ 0.          0.04786745  0.09562516 ...  0.92901469  0.94566277
#    0.96014281]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.074356602640936
# i: 0
# antes_nm64_nss4_ypos7074_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos7074_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos7074_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos7074_posDAS3_real.csv
# i: 4
# antes_nm64_nss4_ypos7074_posDAS4_real.csv
# i: 5
# antes_nm64_nss4_ypos7074_posDAS5_real.csv
# i: 6
# antes_nm64_nss4_ypos7074_posDAS6_real.csv
# i: 7
# antes_nm64_nss4_ypos7074_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos7074_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos7074_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos7074_posDAS10_real.csv
# Posições:
# [[1.73504561 1.61065903]
#  [5.87314287 1.61065903]
#  [4.94699228 1.61065903]
#  [0.6142654  1.61065903]]
#
# Sinais:
# [[ 0.         -0.88591532  0.82185834 ...  0.89391458 -0.01753927
#   -0.87764351]
#  [ 0.          0.34994604 -0.65563781 ... -0.87718437  0.65369199
#   -0.34753354]
#  [ 0.          0.90148353  0.78034833 ...  0.41539391  0.999815
#    0.45007278]
#  [ 0.          0.28709515 -0.55001808 ...  0.93222323 -0.78908348
#    0.57950618]]
#
# Número de microfones:
# 64
#
# Y position:
# 1.6106590255850983
# i: 0
# antes_nm64_nss4_ypos1611_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos1611_posDAS1_real.csv
# i: 2
# depois_nm64_nss4_ypos1611_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos1611_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos1611_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos1611_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos1611_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos1611_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos1611_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos1611_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos1611_posDAS10_real.csv
# Posições:
# [[5.10362945 6.31677938]
#  [1.84145904 6.31677938]
#  [4.80062398 6.31677938]]
#
# Sinais:
# [[ 0.          0.69918491 -0.99975175 ... -0.59666147 -0.13451335
#    0.78899965]
#  [ 0.          0.84037801  0.91097101 ... -0.77672049  0.10832518
#    0.89414515]
#  [ 0.          0.0792802  -0.15806132 ...  0.9895527  -0.975008
#    0.95432538]]
#
# Número de microfones:
# 64
#
# Y position:
# 6.316779376183388
# i: 0
# antes_nm64_nss3_ypos6317_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos6317_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos6317_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos6317_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos6317_posDAS4_real.csv
# i: 5
# antes_nm64_nss3_ypos6317_posDAS5_real.csv
# i: 6
# antes_nm64_nss3_ypos6317_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos6317_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos6317_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos6317_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos6317_posDAS10_real.csv
# Posições:
# [[0.0561098  6.72664478]
#  [2.17068728 6.72664478]
#  [5.02833969 6.72664478]
#  [1.05802397 6.72664478]]
#
# Sinais:
# [[ 0.          0.98852833  0.29860581 ...  0.11564936  0.99936257
#    0.18622916]
#  [ 0.          0.073583    0.14676704 ...  0.90945257  0.9375835
#    0.96063104]
#  [ 0.          0.83220312  0.9228648  ...  0.74592622  0.96786544
#    0.32738019]
#  [ 0.          0.01420342 -0.02840398 ... -0.58486221  0.59632408
#   -0.60766563]]
#
# Número de microfones:
# 64
#
# Y position:
# 6.726644776393657
# i: 0
# antes_nm64_nss4_ypos6727_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos6727_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos6727_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos6727_posDAS3_real.csv
# i: 4
# antes_nm64_nss4_ypos6727_posDAS4_real.csv
# i: 5
# antes_nm64_nss4_ypos6727_posDAS5_real.csv
# i: 6
# antes_nm64_nss4_ypos6727_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos6727_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos6727_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos6727_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos6727_posDAS10_real.csv
# Posições:
# [[2.34966533 5.30106922]]
#
# Sinais:
# [[ 0.         -0.48192759  0.84454055 ... -0.45838383  0.82995621
#   -0.99604977]]
#
# Número de microfones:
# 64
#
# Y position:
# 5.301069218015365
# i: 0
# antes_nm64_nss1_ypos5301_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos5301_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos5301_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos5301_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos5301_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos5301_posDAS5_real.csv
# i: 6
# depois_nm64_nss1_ypos5301_posDAS6_real.csv
# i: 7
# depois_nm64_nss1_ypos5301_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos5301_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos5301_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos5301_posDAS10_real.csv
# Posições:
# [[5.1998138  4.83687134]
#  [1.25457283 4.83687134]
#  [4.78213934 4.83687134]]
#
# Sinais:
# [[ 0.          0.11906971  0.23644528 ... -0.59276841 -0.49265587
#   -0.38553372]
#  [ 0.          0.29917564 -0.57094563 ...  0.5188794  -0.23936418
#   -0.06207772]
#  [ 0.          0.79481594  0.96466902 ... -0.98722013 -0.72575898
#    0.10636563]]
#
# Número de microfones:
# 64
#
# Y position:
# 4.836871340056802
# i: 0
# antes_nm64_nss3_ypos4837_posDAS0_real.csv
# i: 1
# antes_nm64_nss3_ypos4837_posDAS1_real.csv
# i: 2
# antes_nm64_nss3_ypos4837_posDAS2_real.csv
# i: 3
# antes_nm64_nss3_ypos4837_posDAS3_real.csv
# i: 4
# antes_nm64_nss3_ypos4837_posDAS4_real.csv
# i: 5
# depois_nm64_nss3_ypos4837_posDAS5_real.csv
# i: 6
# depois_nm64_nss3_ypos4837_posDAS6_real.csv
# i: 7
# depois_nm64_nss3_ypos4837_posDAS7_real.csv
# i: 8
# depois_nm64_nss3_ypos4837_posDAS8_real.csv
# i: 9
# depois_nm64_nss3_ypos4837_posDAS9_real.csv
# i: 10
# depois_nm64_nss3_ypos4837_posDAS10_real.csv
# Posições:
# [[5.39795172 7.20415985]]
#
# Sinais:
# [[ 0.         -0.99606259 -0.17660754 ... -0.07247614 -0.9998683
#   -0.10480617]]
#
# Número de microfones:
# 64
#
# Y position:
# 7.204159847683975
# i: 0
# antes_nm64_nss1_ypos7204_posDAS0_real.csv
# i: 1
# antes_nm64_nss1_ypos7204_posDAS1_real.csv
# i: 2
# antes_nm64_nss1_ypos7204_posDAS2_real.csv
# i: 3
# antes_nm64_nss1_ypos7204_posDAS3_real.csv
# i: 4
# antes_nm64_nss1_ypos7204_posDAS4_real.csv
# i: 5
# antes_nm64_nss1_ypos7204_posDAS5_real.csv
# i: 6
# antes_nm64_nss1_ypos7204_posDAS6_real.csv
# i: 7
# antes_nm64_nss1_ypos7204_posDAS7_real.csv
# i: 8
# depois_nm64_nss1_ypos7204_posDAS8_real.csv
# i: 9
# depois_nm64_nss1_ypos7204_posDAS9_real.csv
# i: 10
# depois_nm64_nss1_ypos7204_posDAS10_real.csv
# Posições:
# [[5.69347948 3.29104378]
#  [2.81616195 3.29104378]
#  [5.45591335 3.29104378]
#  [3.67427429 3.29104378]]
#
# Sinais:
# [[ 0.          0.17911701 -0.35244057 ... -0.21415859  0.38565646
#   -0.54468049]
#  [ 0.          0.85939491 -0.87883858 ...  0.94341783 -0.1974004
#   -0.74155128]
#  [ 0.          0.83255888 -0.9223696  ...  0.82831915 -0.92528281
#    0.19677679]
#  [ 0.         -0.97682207 -0.4181832  ... -0.12859126 -0.99623751
#   -0.2979038 ]]
#
# Número de microfones:
# 64
#
# Y position:
# 3.2910437798212677
# i: 0
# antes_nm64_nss4_ypos3291_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos3291_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos3291_posDAS2_real.csv
# i: 3
# antes_nm64_nss4_ypos3291_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos3291_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos3291_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos3291_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos3291_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos3291_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos3291_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos3291_posDAS10_real.csv
# Posições:
# [[0.38298124 1.43672347]
#  [5.57894513 1.43672347]]
#
# Sinais:
# [[ 0.         -0.53268235 -0.9016344  ...  0.92627171  0.58317316
#    0.06082497]
#  [ 0.          0.43470898  0.78297259 ... -0.18173829 -0.59113797
#   -0.88298513]]
#
# Número de microfones:
# 64
#
# Y position:
# 1.436723470666036
# i: 0
# antes_nm64_nss2_ypos1437_posDAS0_real.csv
# i: 1
# antes_nm64_nss2_ypos1437_posDAS1_real.csv
# i: 2
# depois_nm64_nss2_ypos1437_posDAS2_real.csv
# i: 3
# depois_nm64_nss2_ypos1437_posDAS3_real.csv
# i: 4
# depois_nm64_nss2_ypos1437_posDAS4_real.csv
# i: 5
# depois_nm64_nss2_ypos1437_posDAS5_real.csv
# i: 6
# depois_nm64_nss2_ypos1437_posDAS6_real.csv
# i: 7
# depois_nm64_nss2_ypos1437_posDAS7_real.csv
# i: 8
# depois_nm64_nss2_ypos1437_posDAS8_real.csv
# i: 9
# depois_nm64_nss2_ypos1437_posDAS9_real.csv
# i: 10
# depois_nm64_nss2_ypos1437_posDAS10_real.csv
# Posições:
# [[2.08574685 2.66808442]
#  [2.94551468 2.66808442]
#  [5.54487991 2.66808442]
#  [1.27503825 2.66808442]]
#
# Sinais:
# [[ 0.          0.75502921  0.99013195 ...  0.13680098 -0.65823165
#   -0.99999432]
#  [ 0.         -0.11951064  0.2373082  ...  0.61594136 -0.70567639
#    0.78529613]
#  [ 0.          0.88055408 -0.83466962 ... -0.73856106  0.94369558
#   -0.15595985]
#  [ 0.         -0.26636749 -0.51348809 ...  0.07135782 -0.19690869
#   -0.45094719]]
#
# Número de microfones:
# 64
#
# Y position:
# 2.6680844222214892
# i: 0
# antes_nm64_nss4_ypos2668_posDAS0_real.csv
# i: 1
# antes_nm64_nss4_ypos2668_posDAS1_real.csv
# i: 2
# antes_nm64_nss4_ypos2668_posDAS2_real.csv
# i: 3
# depois_nm64_nss4_ypos2668_posDAS3_real.csv
# i: 4
# depois_nm64_nss4_ypos2668_posDAS4_real.csv
# i: 5
# depois_nm64_nss4_ypos2668_posDAS5_real.csv
# i: 6
# depois_nm64_nss4_ypos2668_posDAS6_real.csv
# i: 7
# depois_nm64_nss4_ypos2668_posDAS7_real.csv
# i: 8
# depois_nm64_nss4_ypos2668_posDAS8_real.csv
# i: 9
# depois_nm64_nss4_ypos2668_posDAS9_real.csv
# i: 10
# depois_nm64_nss4_ypos2668_posDAS10_real.csv

# %%
import numpy as np
from sklearn.decomposition import PCA

array_original = np.random.rand(64, 10000)

pca = PCA(n_components=1)
array_reduzido = pca.fit_transform(array_original.T)

print("Shape do array reduzido:", array_reduzido.shape)
# Out:
# Shape do array reduzido: (10000, 1)

# %%
array_original.T.shape
# Out:
# (10000, 64)
